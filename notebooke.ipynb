# %% [markdown]
# #### Imports

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from tqdm import tqdm
import json
import time
import re
import random
import pandas as pd
from secret_key import google_key

# %% [markdown]
# ##### LLM instance initiation

# %%
llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash-lite",
    temperature=0,
    google_api_key=google_key
)

# %% [markdown]
# ##### An example of what the language chain will do

# %%
prompt1 = ChatPromptTemplate.from_template(
    "What is the original language of {Title} written by {Author}? Relpy with a single word in English"
)

chain1 = prompt1 | llm

# %%
response = chain1.invoke({"Title": "أهل الكهف", "Author": "توفيق الحكيم"})
response.content
# Out:
# 'Arabic'

# %% [markdown]
# #### Data Load & Preprocessing

# %%
df = pd.read_csv("goodreads_data.csv")
df.sample()
# Out:
#       Book Id                                              Title  \
# 198  16429619  The Kiss of Deception (The Remnant Chronicles,...
#
#               Author Additional Authors ISBN  ISBN13  My Rating  \
# 198  Mary E. Pearson                NaN  NaN     NaN          3
#
#      Average Rating   Publisher  Number of Pages  Year Published  \
# 198            3.92  Henry Holt            492.0          2014.0
#
#      Original Publication Year   Date Read Date Added Bookshelves My Review
# 198                     2014.0  22/01/2021  7/01/2021        read       NaN

# %%
df = df.drop(columns=['ISBN', 'ISBN13', 'My Review', 'Additional Authors', 'Publisher'], axis=1)
df.sample()
# Out:
#      Book Id                                   Title        Author  My Rating  \
# 305      968  The Da Vinci Code (Robert Langdon, #2)  Dan    Brown          0
#
#      Average Rating  Number of Pages  Year Published  \
# 305            3.93            489.0          2006.0
#
#      Original Publication Year Date Read  Date Added Bookshelves
# 305                     2003.0       NaN  31/12/2020     to-read

# %% [markdown]
# #### A function to invoke the chain with respect to thr rate-limit

# %%
def invoke_chain(chain, input_data, max_retries=3, base_delay=1):
    for attempt in range(max_retries):
        try:
            result = chain.invoke(input_data)
            return result
        except Exception as e:
            if "rate_limit" in str(e).lower() or "429" in str(e):
                if attempt < max_retries - 1:
                    delay = base_delay * (2 ** attempt) + random.uniform(0,1)
                    print(f"Rate limited. Retrying in {delay:.1f} seconds...")
                    time.sleep(delay)
                else:
                    print(f"Max retries reached. Error: {e}")
                    raise e
            else:
                raise e

# %% [markdown]
# #### A function to clean the parsed LLM response

# %%
def parse_llm_response(response, num_items, categories):
    cleaned = response.strip()

    cleaned = re.sub(r"```json|```", "", cleaned).strip()

    try:
        result = json.loads(cleaned)
        if isinstance(result, list) and len(result) >= num_items:
            return result[:num_items]
    except:
        pass

    found = []
    for g in categories:
        if g.lower() in cleaned.lower():
            found.append(g)

    if found:
        while len(found) < num_items:
            found.append(found[0])
        return found[:num_items]

    return ["Unknown"] * num_items

# %% [markdown]
# #### A function to add a new column (in batches) to the existing data frame

# %%
def add_column(df, classes, category, chain, batch_size=10, delay_between_batches=2):
    all_classes = []
    genres_str = ", ".join(classes)

    for i in tqdm(range(0, len(df), batch_size)):
        batch = df.iloc[i:i+batch_size]

        book_text = "\n".join([
            f"{idx+1}. {row['Title']} by {row['Author']}"
            for idx, row in batch.iterrows()
        ])

        try:
            response = invoke_chain(
                chain, 
                {"books": book_text, "genres": genres_str}
            )

            parsed = parse_llm_response(response, len(batch), classes)
            all_classes.extend(parsed)

        except Exception as e:
            print(f"Error in batch {i//batch_size + 1}: {e}")
            all_classes.extend(["Unknown"] * len(batch))

        if i + batch_size < len(df):
            time.sleep(delay_between_batches)

    df[category] = all_classes
    return df

# %% [markdown]
# ##### Testing the language chain with extracting the language of the book

# %%
languages_list = ["English", "German", "Russian", "Arabic", "Swedish", "Japanese", "Portugese"]

language_prompt = ChatPromptTemplate.from_template("""
Determine the language of these books based on their titles and authors.

Books:
{books}

For each book, return only the language name in English.
Return as a JSON array with one language per book in the same order.
Example: ["English", "French", "Spanish"]

Only return the array, no other text.
""")

language_chain = language_prompt | llm | StrOutputParser()

# %%
df = add_column(df.copy(), languages_list, "Language", language_chain)
# Out:
#  47%|████▋     | 15/32 [00:40<00:45,  2.66s/it]Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 2.0 seconds as it raised ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite
# Please retry in 31.179498861s. [links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , retry_delay {
#   seconds: 31
# }
# ].
# Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 4.0 seconds as it raised ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite
# Please retry in 29.079130672s. [links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , retry_delay {
#   seconds: 29
# }
# ].
# Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 8.0 seconds as it raised ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite
# Please retry in 24.992916314s. [links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , retry_delay {
#   seconds: 24
# }
# ].
# Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 16.0 seconds as it raised ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite
# Please retry in 16.896200762s. [links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , retry_delay {
#   seconds: 16
# }
# ].
#  97%|█████████▋| 31/32 [01:51<00:02,  2.64s/it]Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 2.0 seconds as it raised ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite
# Please retry in 19.636530072s. [links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , retry_delay {
#   seconds: 19
# }
# ].
# Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 4.0 seconds as it raised ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite
# Please retry in 17.539070796s. [links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , retry_delay {
#   seconds: 17
# }
# ].
# Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 8.0 seconds as it raised ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite
# Please retry in 13.448550629s. [links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , retry_delay {
#   seconds: 13
# }
# ].
# 100%|██████████| 32/32 [02:06<00:00,  3.96s/it]

# %%
df.sample(10)
# Out:
#        Book Id                                              Title  \
# 268    3777732         City of Glass (The Mortal Instruments, #3)
# 2     59651555        Stuck with You (The STEMinist Novellas, #2)
# 58     3335314                              التفكير فريضة إسلامية
# 288   35702241  The Shadows Between Us (The Shadows Between Us...
# 0      5935144                                        خان الخليلي
# 235   28686840                            Holding Up the Universe
# 220   27883214                              Caraval (Caraval, #1)
# 147   58064046                                            Gallant
# 309    1582996         City of Ashes (The Mortal Instruments, #2)
# 40   198281740                                The Life Impossible
#
#                  Author  My Rating  Average Rating  Number of Pages  \
# 268     Cassandra Clare          5            4.27            541.0
# 2         Ali Hazelwood          2            3.56            127.0
# 58    عباس محمود العقاد          4            3.94            152.0
# 288  Tricia Levenseller          3            3.82            326.0
# 0        Naguib Mahfouz          4            3.92            280.0
# 235      Jennifer Niven          3            3.67            391.0
# 220    Stephanie Garber          4            3.97            407.0
# 147         V.E. Schwab          3            3.70            338.0
# 309     Cassandra Clare          4            4.10            453.0
# 40            Matt Haig          2            3.48            324.0
#
#      Year Published  Original Publication Year   Date Read  Date Added  \
# 268          2009.0                     2009.0   1/07/2020  19/08/2020
# 2            2022.0                     2022.0  20/09/2025  20/09/2025
# 58           2008.0                     1962.0  15/04/2024   8/04/2024
# 288          2020.0                     2020.0   2/04/2021  31/03/2021
# 0            2006.0                     1945.0   2/11/2025   2/01/2024
# 235          2016.0                     2016.0   1/01/2019  23/06/2020
# 220          2017.0                     2016.0  21/08/2021   9/04/2021
# 147          2022.0                     2022.0   1/08/2022  21/12/2021
# 309          2008.0                     2008.0  19/08/2020  27/07/2020
# 40           2024.0                     2024.0   1/11/2024  23/10/2024
#
#     Bookshelves Language
# 268        read  English
# 2          read  English
# 58         read   Arabic
# 288        read  English
# 0          read   Arabic
# 235        read  English
# 220        read  English
# 147        read  English
# 309        read  English
# 40         read  English

# %%
df['Language'].value_counts()
# Out:
# Language
# English       246
# Arabic         49
# Russian         8
# Japanese        4
# Persian         2
# Swedish         2
# French          1
# German          1
# Portuguese      1
# Name: count, dtype: int64

# %% [markdown]
# #### Applying the same chain to extract book genres

# %%
genre_list = [
    "Non-Fiction", "Fantasy", "Science Fiction", "Romance", "Mystery",
    "Thriller", "Young Adult", "Poetry", "Classic"
]

genre_prompt = ChatPromptTemplate.from_template("""
You are a book classification model.

Given the following books (title and author), classify each one into EXACTLY one of these genres:
{genres}

Books:
{books}

Return ONLY a JSON array containing the genre for each book in the same order.
Example: ["Fiction", "Romance", "Fantasy"]

Only return the JSON array. No explanation.
""")

genre_chain = genre_prompt | llm | StrOutputParser()

# %%
df= add_column(df.copy(), genre_list, "Genre", genre_chain)
# Out:
#  47%|████▋     | 15/32 [00:39<00:44,  2.61s/it]Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 2.0 seconds as it raised ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite
# Please retry in 25.277116696s. [links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , retry_delay {
#   seconds: 25
# }
# ].
# Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 4.0 seconds as it raised ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite
# Please retry in 23.18912163s. [links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , retry_delay {
#   seconds: 23
# }
# ].
# Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 8.0 seconds as it raised ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite
# Please retry in 19.093068855s. [links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , retry_delay {
#   seconds: 19
# }
# ].
#  97%|█████████▋| 31/32 [01:35<00:02,  2.56s/it]Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 2.0 seconds as it raised ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite
# Please retry in 29.374282054s. [links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , retry_delay {
#   seconds: 29
# }
# ].
# Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 4.0 seconds as it raised ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite
# Please retry in 27.29750478s. [links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , retry_delay {
#   seconds: 27
# }
# ].
# Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 8.0 seconds as it raised ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite
# Please retry in 23.208683928s. [links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , retry_delay {
#   seconds: 23
# }
# ].
# Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 16.0 seconds as it raised ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite
# Please retry in 15.124605204s. [links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.5-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
#   quota_value: 15
# }
# , retry_delay {
#   seconds: 15
# }
# ].
# 100%|██████████| 32/32 [02:06<00:00,  3.95s/it]

# %%
df.sample(10)
# Out:
#       Book Id                                        Title  \
# 219  36329818                      Legendary (Caraval, #2)
# 83    7651652                                       E.S.P.
# 303  17699853           Chain of Gold (The Last Hours, #1)
# 180  16130537                                   The Humans
# 126  23272028  A Study in Charlotte (Charlotte Holmes, #1)
# 250  22540125                After We Collided (After, #2)
# 156  59009928            There Are No Saints (Sinners, #1)
# 167  15717943                      Hopeless (Hopeless, #1)
# 12   58784475         Tomorrow, and Tomorrow, and Tomorrow
# 287  43263680                 Ninth House (Alex Stern, #1)
#
#                  Author  My Rating  Average Rating  Number of Pages  \
# 219    Stephanie Garber          5            4.10            451.0
# 83      أحمد خالد توفيق          0            3.60            329.0
# 303     Cassandra Clare          3            4.37            582.0
# 180           Matt Haig          0            4.08            285.0
# 126  Brittany Cavallaro          0            3.75            336.0
# 250           Anna Todd          1            3.72            674.0
# 156         Sophie Lark          1            3.79            258.0
# 167      Colleen Hoover          3            4.22            410.0
# 12      Gabrielle Zevin          3            4.12            401.0
# 287       Leigh Bardugo          0            4.00            461.0
#
#      Year Published  Original Publication Year   Date Read  Date Added  \
# 219          2018.0                     2018.0  28/08/2021  16/07/2021
# 83           2009.0                     2009.0         NaN  21/12/2023
# 303          2020.0                     2020.0  24/12/2020  21/12/2020
# 180          2013.0                     2013.0         NaN   5/12/2021
# 126          2016.0                     2016.0         NaN  22/02/2023
# 250          2014.0                     2013.0   1/01/2018  29/04/2021
# 156          2021.0                     2021.0  12/06/2022  12/02/2022
# 167          2012.0                     2012.0  20/02/2022   6/02/2022
# 12           2022.0                     2022.0   6/07/2025  11/06/2025
# 287          2019.0                     2019.0         NaN  14/04/2021
#
#     Bookshelves Language            Genre
# 219        read  English          Fantasy
# 83         read   Arabic  Science Fiction
# 303        read  English          Fantasy
# 180     to-read  English  Science Fiction
# 126     to-read  English      Young Adult
# 250        read  English          Romance
# 156        read  English          Romance
# 167        read  English          Romance
# 12         read  English          Romance
# 287     to-read  English      Young Adult

# %%
df['Genre'].value_counts()
# Out:
# Genre
# Classic               72
# Fantasy               68
# Young Adult           60
# Romance               45
# Non-Fiction           31
# Mystery               20
# Thriller               8
# Science Fiction        8
# Poetry                 1
# Historical Fiction     1
# Name: count, dtype: int64

# %%
df.to_csv("goodreads.csv")
